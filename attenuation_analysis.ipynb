# %%
import numpy as np
from ROOT import TCanvas, TGraphErrors, TF1, TGraph,TLatex
from ROOT import gROOT
from array import array
import math
import ROOT
# Out:
# Welcome to JupyROOT 6.16/00

# %%
import math
import matplotlib.pyplot as plt

# %%
al = [0,5.29,7.10,10.9,14.6,21.5,29.6,42.1,62.4,102.6,138.6,182.9]
al_tau = []
for i in al:
    x = i*10**(-3)
    al_tau.append(x)
al2 = [.226,.262,.312,.357,.428,.526,.610,.748,.951,1.177,1.593]
for i in al2:
    al_tau.append(i)

# %%
#part 0
HV = [350,400,450,475,500,550,575,600,625,630,640,650,660,675,700]
count_0 = [1,331,1007,1232,1346,1488,1576,1614,1778,1737,1821,1863,2114,2663,2931]
count_0_error = []
for i in count_0:
    x = math.sqrt(i)
    count_0_error.append(x)
#CHOSEN VOLT = 575 V
error_count_0 = []
for i in count_0:
    x = math.sqrt(i)
    error_count_0.append(x)
    #plt.scatter(HV,count_0)
t = []
for i in range(len(al_tau)):
    x = 0
    t.append(x)
    
HV_er = []
for i in range(len(HV)):
    x = 0
    HV_er.append(x)

# %%
print len(HV)
print len(HV_er)
print len(t)
# Out:
# 15
# 15
# 23

# %%
al_tau   =  array( 'f', al_tau )
count_0 =  array( 'f', count_0)
t= array('f',t)
error_count_0=array('f',error_count_0)

HV = array('f' , HV)
HV_er = array('f', HV_er)
#igma_F = array('f', sigma_F)

# %%
ndata0 = len(HV)

# %%
# NO FILTER, 30 sec
no_filter_count = 4596

# %%
c1 = TCanvas( 'c1', '..', 200, 10, 700, 500 )
             
mygraph0 = TGraphErrors(ndata0,HV,count_0,HV_er,error_count_0)
mygraph0.Draw("AP")
mygraph0.SetTitle("Plateauing")
mygraph0.SetLineColor( 4 )
mygraph0.SetLineWidth( 2 )
mygraph0.SetMarkerColor( 9)
mygraph0.SetMarkerStyle( 7 )

mygraph0.GetXaxis().SetTitle( 'HV(Volts)' )
mygraph0.GetYaxis().SetTitle( ' Counts')
c1.Draw()

# %%
#PART_1 / Al
#EACH 30 SEC

al_number = []
for i in range(4,26):
    al_number.append(i)

    
count_1 = [4596,4198,3847,3733,3628,3267,2887,2496,2307,2120,1962,1861,2055,1890,2028,2016,1894,1954,1874,1840,1858,1866,1790]
count_1_error = []
for i in count_1:
    x = math.sqrt(i)
    count_1_error.append(x)
#print (count_1_error)
#plt.scatter(al_tau,count_1)
print count_1_error
# Out:
# [67.79380502671317, 64.79197481170026, 62.02418882984283, 61.09828148156051, 60.23288138550239, 57.15767664977295, 53.73081052803875, 49.95998398718719, 48.03123983409131, 46.04345773288535, 44.294469180700204, 43.139309220245984, 45.332107826572546, 43.474130238568314, 45.033320996790806, 44.8998886412873, 43.520110293977886, 44.204072210600685, 43.289721643826724, 42.89522117905443, 43.104524124504614, 43.197222132910355, 42.30839160261236]

# %%
count_1 = array('f', count_1 )
count_1_error = array('f', count_1_error)

# %%
ndata1 = len(al_tau)
print len(al_tau)
print len(count_1)
print len(t)
print len(count_1_error)
print count_1_error
print count_1
# Out:
# 23
# 23
# 23
# 23
# array('f', [67.79380798339844, 64.79197692871094, 62.02418899536133, 61.09828186035156, 60.232879638671875, 57.157676696777344, 53.730812072753906, 49.959983825683594, 48.0312385559082, 46.04345703125, 44.29446792602539, 43.13930892944336, 45.33210754394531, 43.47412872314453, 45.033321380615234, 44.89988708496094, 43.520111083984375, 44.204071044921875, 43.28972244262695, 42.89522171020508, 43.104522705078125, 43.19722366333008, 42.30839157104492])
# array('f', [4596.0, 4198.0, 3847.0, 3733.0, 3628.0, 3267.0, 2887.0, 2496.0, 2307.0, 2120.0, 1962.0, 1861.0, 2055.0, 1890.0, 2028.0, 2016.0, 1894.0, 1954.0, 1874.0, 1840.0, 1858.0, 1866.0, 1790.0])

# %%
c1 = TCanvas( 'c1', '..', 200, 10, 700, 500 )
             
mygraph = TGraphErrors(ndata1,al_tau,count_1, t, count_1_error)
mygraph.Draw("AP")
mygraph.SetTitle("Aluminum Absorbers")
mygraph.SetLineColor( 4 )
mygraph.SetLineWidth( 2 )
mygraph.SetMarkerColor( 9)
mygraph.SetMarkerStyle( 7 )

mygraph.GetXaxis().SetTitle( 'Areal Thickness (g/cm²)' )
mygraph.GetYaxis().SetTitle( ' Counts')
c1.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %%
#l1=TF1("l1", "([0]*sin(x/2-[1]))**(-4)")
l1 = TF1("l1", "[0]*exp(-[1]*x)+[2]*exp(-[3]*x)")
#l2=TF1('l2','gaus')
#l2=TF1('l2','pol1')
l1.SetParameters(1500,2000)
#l1.TLegend()
mygraph.Fit(l1,'','')
#mygraph.Fit(l2,'','')
#legend = ROOT.TLegend (0.7 ,0.6 ,0.85 ,0.75)
#legend.SetLineWidth (0)
#chi2 = l1.GetChisquare()





c1.Draw()
# Out:
#  FCN=39.8086 FROM MIGRAD    STATUS=CONVERGED     377 CALLS         378 TOTAL
#                      EDM=1.5064e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           1.99121e+03   2.07566e+01   3.20212e-02   1.53429e-04
#    2  p1           6.82055e-02   1.51420e-02   2.82292e-05  -1.50331e-01
#    3  p2           2.57858e+03   4.79843e+01   1.03751e-01   1.86091e-05
#    4  p3           3.49325e+01   1.44262e+00   2.84018e-03  -1.18574e-03

# %%
#part_2
lead_tau = [0,0.9,1.8,3.6,7.2,2.7,4.5,8.1,5.4,9.0,10.8]
lead_count = [4596,2641,2239,1796,1305,2000,1594,1210,1491,1080,891]
lead_error = []
for i in lead_count:
    x = math.sqrt(i)
    lead_error.append(x)
#plt.scatter(lead_tau,lead_count)
ndata2 = len(lead_tau)
err_lead = []
for i in range(ndata2):
    x = 0
    err_lead.append(x)
print ndata2
print len(lead_count)
# Out:
# 11
# 11

# %%
lead_tau = array('f', lead_tau)
lead_count = array('f', lead_count)
lead_error = array('f', lead_error)
err_lead = array('f', err_lead)

# %%
c1 = TCanvas( 'c1', '..', 200, 10, 700, 500 )
             
mygraph = TGraphErrors(ndata2,lead_tau,lead_count,  err_lead,lead_error)
mygraph.Draw("AP")
mygraph.SetTitle("Lead Absorbers")
mygraph.SetLineColor( 4 )
mygraph.SetLineWidth( 2 )
mygraph.SetMarkerColor( 9)
mygraph.SetMarkerStyle( 7 )

mygraph.GetXaxis().SetTitle( 'Areal Thickness (g/cm²)' )
mygraph.GetYaxis().SetTitle( ' Counts')
c1.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %%
#l1=TF1("l1", "([0]*sin(x/2-[1]))**(-4)")
l1 = TF1("l1", "[0]*exp(-[1]*x)+[2]*exp(-[3]*x)")
#l2=TF1('l2','gaus')
#l2=TF1('l2','pol1')
l1.SetParameters(10,0.0001,10,0.0001)
#l1.TLegend()
mygraph.Fit(l1,'','',0,12)
#mygraph.Fit(l2,'','')
#legend = ROOT.TLegend (0.7 ,0.6 ,0.85 ,0.75)
#legend.SetLineWidth (0)
#chi2 = l1.GetChisquare()





c1.Draw()
# Out:
#  FCN=6.22225 FROM MIGRAD    STATUS=CONVERGED     537 CALLS         538 TOTAL
#                      EDM=1.38998e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           2.04590e+03   8.78460e+01   8.70409e-02   3.08918e-06
#    2  p1           2.05422e+00   2.47662e-01   2.25129e-04  -2.55378e-03
#    3  p2           2.54754e+03   5.81072e+01   2.56934e-02   2.11064e-06
#    4  p3           9.57569e-02   3.65444e-03   1.93636e-06   8.87242e-02

# %%
#part_3 #g/cm^2

poly_tau = [0,0.07, 0.14, 0.29, 0.58, 0.21, 0.36, 0.65, 0.43, 0.72,0.87]
#2318
poly_count = [4596,2318,2147,2063,1985,2147,2117,1976,2029,1963,1966]
#plt.scatter(poly_tau, poly_count)

# %%
ndata3 = len(poly_tau)
error_poly_count = []
for i in poly_count:
    x = math.sqrt(i)
    error_poly_count.append(x)
error_poly_tau = []
for i in range(ndata3):
    x = 0
    error_poly_tau.append(x)
print ndata3
# Out:
# 11

# %%
poly_tau = array('f', poly_tau)
poly_count = array('f',poly_count)
error_poly_count = array('f',error_poly_count)
error_poly_tau = array('f', error_poly_tau)

# %%
c1 = TCanvas( 'c1', '..', 200, 10, 700, 500 )
             
mygraph = TGraphErrors(ndata3,poly_tau,poly_count,  error_poly_tau,error_poly_count)
mygraph.Draw("AP")
mygraph.SetTitle("Polyethylene Absorbers")
mygraph.SetLineColor( 4 )
mygraph.SetLineWidth( 2 )
mygraph.SetMarkerColor( 9)
mygraph.SetMarkerStyle( 7 )

mygraph.GetXaxis().SetTitle( 'Areal Thickness (g/cm²)' )
mygraph.GetYaxis().SetTitle( ' Counts')
c1.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %%
#l1=TF1("l1", "([0]*sin(x/2-[1]))**(-4)")
l1 = TF1("l1", "[0]*exp(-[1]*x)+[2]*exp(-[3]*x)")
#l2=TF1('l2','gaus')
#l2=TF1('l2','pol1')
l1.SetParameters(0,1)
#l1.TLegend()
mygraph.Fit(l1,'','')
#mygraph.Fit(l2,'','')
#legend = ROOT.TLegend (0.7 ,0.6 ,0.85 ,0.75)
#legend.SetLineWidth (0)
#chi2 = l1.GetChisquare()





c1.Draw()
# Out:
#  FCN=3.15323 FROM MIGRAD    STATUS=CONVERGED     445 CALLS         446 TOTAL
#                      EDM=4.0968e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           2.41710e+03   7.90361e+01   3.90784e-01   7.01632e-06
#    2  p1           3.87469e+01   5.20745e+00   5.81493e-02  -2.50277e-04
#    3  p2           2.17889e+03   3.95349e+01   3.25191e-01   1.63750e-05
#    4  p3           1.38486e-01   3.43503e-02   2.44608e-04   2.51041e-02
